# %% [markdown]
# #### STEP1. 엑셀파일로 만드는 함수 연습.  10 times
# #### STEP2. 여러 페이지 읽어오기 5 times
# #### STEP3. 엑셀 파일 읽어오기 10 times
# #### STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식) 5 times
# #### STEP5. 공공데이터 api이용하고 엑셀 파일로 저장하기. (xml형식) 5 times

# %%
#step1. 엑셀파일 만드는 함수 연습_1
import openpyxl
def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname
    
    for item in listdata:
        excel_sheet.append(item)
    excel_file.save(filename)
    excel_file.close()

# %%
#step1. 엑셀파일 만드는 함수 연습_2
import openpyxl
def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetnmae
    
    for item in listdata:
        excel_sheet.append(item)
    excel_file.save(filename)
    excel_file.close()

# %%
#step1. 엑셀파일 만드는 함수 연습_3
import openpyxl
def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname !='':
        excel_sheet.title = sheetname
    for item in listdata:
        excel_sheet.append(item)
        
    excel_file.save(filename)
    excel_file.close()

# %%
#step1. 엑셀파일 만드는 함수 연습_4
import openpyxl
def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname
        
    for item in listdata:
        excel_sheet.append(item)
        
    excel_file.save(filename)
    excel_file.close()

# %%
#step1. 엑셀파일 만든느 함수 연습_5
import openpyxl
def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname
        
    for item in listdata:
        excel_sheet.append(item)
    excel_file.save(filename)
    excel_file.close()

# %%
#step1. 엑셀파일 만든느 함수 연습_6
import openpyxl 

def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname 
    for data in listdata:
        excel_sheet.append(data)
    excel_file.save(filename)
    excel_file.close()

# %%
#step1. 엑셀파일 만든느 함수 연습_7
import openpyxl 

def write_excel_template(filename, sheetname, datalist):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname
        
    for item in datalist: 
        excel_sheet.append(item)
        
    excel_file.save(filename)
    
    excel_file.close()

# %%
#step1. 엑셀파일 만든느 함수 연습_8
import openpyxl 

def write_excel_template(filename, sheetname, datalist):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname
        
    for item in datalist:
        excel_sheet.append(item)
    
    excel_file.save(filename)
    
    excel_file.close()

# %%
#step1. 엑셀파일 만든느 함수 연습_9
import openpyxl

def write_excel_template(filename, sheetname, datalist):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname 
        
        
    for item in datalist:
        excel_sheet.append(item)
        
    excel_file.save(filename)
    
    excel_file.close()

# %%
#step1. 엑셀파일 만든느 함수 연습_10
import openpyxl

def write_excel_template(filename, sheetname, datalist):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column.dimensions['A'].width = 100
    
    if sheetname != '':
        excel_sheet.title = sheetname 
    
    for data list datalist: 
        excel_sheet.append(data)
        
    excel_file.save(filename)
    
    excel_file.close()

# %%
#STEP2. 여러 페이지 읽어오기_1       
import requests
from bs4 import BeautifulSoup
product_lists = list()
#num = 0

res_1 = requests.get('https://davelee-fun.github.io/')
soup_1 = BeautifulSoup(res_1.content,'html.parser')
data_top = soup_1.select('div.col-12.col-md-12.col-lg-7')

for data in data_top:
    product_name_top = data.select_one('h4.card-text')
    product_date_top = data.select_one('span.post-date')
    product_info_top = [product_name_top.get_text().strip('\n\n'), product_date_top.get_text()]
    product_lists.append(product_info_top)

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')

    data = soup.select('div.col-lg-4.col-md-6.mb-30px.card-group')
    for item in data:
        product_name = item.select_one('h4.card-text')
        product_date = item.select_one('span.post-date')
        product_info = [product_name.get_text().strip('\n\n'), product_date.get_text()]
        product_lists.append(product_info)

for index, product_list in enumerate(product_lists):
    print(index+1, product_list)
# Out:
# 1 ['상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루', '05 Jun 2020']
# 2 ['상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지', '05 Jun 2020']
# 3 ['상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조', '05 Jun 2020']
# 4 ['상품명: 보드래 헬로우 누빔 매트리스커버, 핑크', '05 Jun 2020']
# 5 ['상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜', '05 Jun 2020']
# 6 ['상품명: 피아블 클래식 방수 매트리스커버, 화이트', '05 Jun 2020']
# 7 ['상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이', '05 Jun 2020']
# 8 ['상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이', '05 Jun 2020']
# 9 ['상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이', '05 Jun 2020']
# 10 ['상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이', '05 Jun 2020']
# 11 ['상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리', '05 Jun 2020']
# 12 ['상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜', '05 Jun 2020']
# 13 ['상품명: WEMAX 다용도 문옷걸이, 화이트, 1개', '05 Jun 2020']
# 14 ['상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑', '05 Jun 2020']
# 15 ['상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이', '05 Jun 2020']
# 16 ['상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이', '05 Jun 2020']
# 17 ['상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크', '05 Jun 2020']
# 18 ['상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜', '05 Jun 2020']
# 19 ['상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트', '05 Jun 2020']
# 20 ['상품명: 프랑떼 항균 방수 매트리스커버, 화이트', '05 Jun 2020']
# 21 ['상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루', '05 Jun 2020']
# 22 ['상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이', '05 Jun 2020']
# 23 ['상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지', '05 Jun 2020']
# 24 ['상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독', '05 Jun 2020']
# 25 ['상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이', '05 Jun 2020']
# 26 ['상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트', '05 Jun 2020']
# 27 ['상품명: 피아블 클래식 방수 매트리스커버, 화이트', '05 Jun 2020']
# 28 ['상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이', '05 Jun 2020']
# 29 ['상품명: 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크', '05 Jun 2020']
# 30 ['상품명: 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이', '05 Jun 2020']
# 31 ['상품명: 아망떼 시어서커 리플 홑이불 패드세트, 웨이크', '05 Jun 2020']
# 32 ['상품명: 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이', '05 Jun 2020']
# 33 ['상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이', '05 Jun 2020']
# 34 ['상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이', '05 Jun 2020']
# 35 ['상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지', '05 Jun 2020']
# 36 ['상품명: 아망떼 시어서커 리플 홑이불 패드세트, 허브티', '05 Jun 2020']
# 37 ['상품명: 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이', '05 Jun 2020']
# 38 ['상품명: 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이', '05 Jun 2020']
# 39 ['상품명: 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우', '05 Jun 2020']
# 40 ['상품명: 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나', '05 Jun 2020']
# 41 ['상품명: 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린', '05 Jun 2020']
# 42 ['상품명: 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비', '05 Jun 2020']
# 43 ['상품명: 슈에뜨룸 비숑 피치스킨 침구세트, 그레이', '05 Jun 2020']
# 44 ['상품명: 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜', '05 Jun 2020']
# 45 ['상품명: 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜', '05 Jun 2020']
# 46 ['상품명: 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이', '05 Jun 2020']
# 47 ['상품명: 예가로드 메리엘 시어서커 누비이불 패드세트, 블루', '05 Jun 2020']
# 48 ['상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트', '05 Jun 2020']
# 49 ['상품명: 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린', '05 Jun 2020']
# 50 ['상품명: 메종 레이스 차렵 이불 세트, 블루', '05 Jun 2020']
# 51 ['상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그린', '05 Jun 2020']
# 52 ['상품명: 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상', '05 Jun 2020']
# 53 ['상품명: 보몽드 메종 레이스 차렵이불 3종 세트, 민트', '05 Jun 2020']
# 54 ['상품명: 슈에뜨룸 체크 피치스킨 침구세트, 모카', '05 Jun 2020']
# 55 ['상품명: 메리엘 시어서커 에어리플 이불세트, 그레이', '05 Jun 2020']
# 56 ['상품명: 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비', '05 Jun 2020']
# 57 ['상품명: 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트', '05 Jun 2020']
# 58 ['상품명: 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이', '05 Jun 2020']
# 59 ['상품명: 이코디 5단 엔틱 도어 행거, 브라운, 1개', '05 Jun 2020']
# 60 ['상품명: 선우랜드 우드볼 도어훅 4구, 실버, 1개', '05 Jun 2020']
# 61 ['상품명: 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개', '05 Jun 2020']
# 62 ['상품명: 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트', '05 Jun 2020']
# 63 ['상품명: 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개', '05 Jun 2020']
# 64 ['상품명: 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개', '05 Jun 2020']
# 65 ['상품명: 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개', '05 Jun 2020']
# 66 ['상품명: 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트', '05 Jun 2020']
# 67 ['상품명: 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개', '05 Jun 2020']
# 68 ['상품명: 선우랜드 우드볼 도어훅 10구, 실버, 1개', '05 Jun 2020']
# 69 ['상품명: 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개', '05 Jun 2020']
# 70 ['상품명: 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1', '05 Jun 2020']
# 71 ['상품명: 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개', '05 Jun 2020']
# 72 ['상품명: 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개', '05 Jun 2020']
# 73 ['상품명: [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량', '05 Jun 2020']
# 74 ['상품명: 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개', '05 Jun 2020']
# 75 ['상품명: 숲속애 웨이브 도어후크 5구, 블랙, 1개', '05 Jun 2020']
# 76 ['상품명: 펀타스틱 다용도 문틀걸이, 화이트, 1개', '05 Jun 2020']
# 77 ['상품명: 선우랜드 우드볼 도어훅 4구, 화이트, 1개', '05 Jun 2020']
# 78 ['상품명: 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개', '05 Jun 2020']
# 79 ['상품명: 까사마루 블랑 접이식 문걸이 건조대, 1개', '05 Jun 2020']
# 80 ['상품명: 선우랜드 우드볼 도어훅 6구, 실버, 1개', '05 Jun 2020']
# 81 ['상품명: 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개', '05 Jun 2020']
# 82 ['상품명: 선우랜드 우드볼 도어훅 10구, 화이트, 1개', '05 Jun 2020']
# 83 ['상품명: 코멧 홈 우드볼 도어행거, 6구, 혼합색상', '05 Jun 2020']
# 84 ['상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조', '05 Jun 2020']
# 85 ['상품명: 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개', '05 Jun 2020']
# 86 ['상품명: 스파이더락 도어후크 8구, 화이트, 1개', '05 Jun 2020']
# 87 ['상품명: 선우랜드 우드볼 도어훅 6구, 화이트, 1개', '05 Jun 2020']
# 88 ['상품명: 코멧 홈 우드볼 도어행거, 10구, 혼합색상', '05 Jun 2020']
# 89 ['상품명: 보드래 헬로우 누빔 매트리스커버, 핑크', '05 Jun 2020']
# 90 ['상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리', '05 Jun 2020']
# 91 ['상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키핑크', '05 Jun 2020']
# 92 ['상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고', '05 Jun 2020']
# 93 ['상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이', '05 Jun 2020']
# 94 ['상품명: 프로텍트어베드 베이직 매트리스 방수커버, 그레이', '05 Jun 2020']

# %%
#STEP2. 여러 페이지 읽어오기_2       
import requests
from bs4 import BeautifulSoup
product_lists = list()

res_1 = requests.get('https://davelee-fun.github.io/')
soup_1 = BeautifulSoup(res_1.content,'html.parser')
data_top = soup_1.select('div.col-12.col-md-12.col-lg-7')

for data in data_top:
    product_name_top = data.select_one('h4.card-text')
    product_date_top = data.select_one('span.post-date')
    product_info_top = [product_name_top.get_text(), product_date_top.get_text()]
    product_lists.append(product_info_top)

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.col-lg-4.col-md-6.mb-30px.card-group')
    for item in data: 
        product_name = item.select_one('h4.card-text')
        product_date = item.select_one('span.post-date')
        product_info = [product_name.get_text(), product_date.get_text()]
        product_lists.append(product_info)
for index, product_list in enumerate(product_lists):
    print(index,product_list)

# %%
#STEP2. 여러 페이지 읽어오기_3       
import requests
from bs4 import BeautifulSoup

product_lists = list()
res_1 = requests.get('https://davelee-fun.github.io/')
soup_1 = BeautifulSoup(res_1.content,'html.parser')
data_top = soup_1.select('div.col-12.col-md-12.col-lg-7')
#첫 페이지 추천 메뉴 부분 
for data in data_top:
    product_name_top = data.select_one('h4.card-text')
    product_date_top = data.select_one('span.post-date')
    product_info_top = [product_name_top.get_text(), product_date_top.get_text()]
    product_lists.append(product_info_top)
    
for page_num in range(10):
    if page_num ==0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.col-lg-4.col-md-6.mb-30px.card-group')
    for item in data: 
        product_name = item.select_one('h4.card-text')
        product_date = item.select_one('span.post-date')
        product_info = [product_name.get_text(), product_date.get_text()]
        product_lists.append(product_info)
for index, product_list in enumerate(product_lists):
    print(index,product_list)

# %%
#STEP2. 여러 페이지 읽어오기_4       
import requests
from bs4 import BeautifulSoup
product_lists = list()
res_1 = requests.get('https://davelee-fun.github.io/')
soup_1 = BeautifulSoup(res_1.content, 'html.parser')
data_top = soup_1.select('div.col-12.col-md-12.col-lg-7')

for data in data_top:
    product_name_top = data.select_one('h4.card-text')
    product_date_top = data.select_one('span.post-date')
    product_info_top = [product_name_top.get_text(), product_date_top.get_text()]
    product_lists.append(product_info_top)
for page_num in range(10):
    if page_num ==0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num +1 ))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.col-lg-4.col-md-6.mb-30px.card-group')
    for item in data: 
        product_name = item.select_one('h4.card-text')
        product_date = item.select_one('span.post-date')
        product_info = [product_name.get_text(), product_date.get_text()]
        product_lists.append(product_info)
for index, product_list in enumerate(product_lists):
    print(index, product_list)

# %%
#STEP2. 여러 페이지 읽어오기_5       
import requests
from bs4 import BeautifulSoup
product_lists = list() 

res_1 = requests.get('https://davelee-fun.github.io/')
soup_1 = BeautifulSoup(res_1.content, 'html.parser')
data_top = soup_1.select('div.col-12.col-md-12.col-lg-7')

for data in data_top:
    product_name_top = data.select_one('h4.card-text')
    product_date_top = data.select_one('span.post-date')
    product_info_top = [product_name_top.get_text(), product_date_top.get_text()]
    product_lists.append(product_info)
    
for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.col-lg-4.col-md-6.mb-30px.card-group')
    for item in data:
        product_name = item.select_one('h4.card-text')
        product_date = item.select_one('span.post-date')
        product_info = [product_name.get_text(), product_date.get_text()]
        product_lists.append(product_info)
for index, product_list in enumerate(product_lists):
    print(index, product_list)
# Out:
# 0 ['상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 1 ['상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 2 ['상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 3 ['상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 4 ['상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜\n\n', '05 Jun 2020']
# 5 ['상품명: 피아블 클래식 방수 매트리스커버, 화이트\n\n', '05 Jun 2020']
# 6 ['상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이\n\n', '05 Jun 2020']
# 7 ['상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이\n\n', '05 Jun 2020']
# 8 ['상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이\n\n', '05 Jun 2020']
# 9 ['상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 10 ['상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리\n\n', '05 Jun 2020']
# 11 ['상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜\n\n', '05 Jun 2020']
# 12 ['상품명: WEMAX 다용도 문옷걸이, 화이트, 1개\n\n', '05 Jun 2020']
# 13 ['상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑\n\n', '05 Jun 2020']
# 14 ['상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이\n\n', '05 Jun 2020']
# 15 ['상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 16 ['상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크\n\n', '05 Jun 2020']
# 17 ['상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜\n\n', '05 Jun 2020']
# 18 ['상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트\n\n', '05 Jun 2020']
# 19 ['상품명: 프랑떼 항균 방수 매트리스커버, 화이트\n\n', '05 Jun 2020']
# 20 ['상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루\n\n', '05 Jun 2020']
# 21 ['상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 22 ['상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지\n\n', '05 Jun 2020']
# 23 ['상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독\n\n', '05 Jun 2020']
# 24 ['상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이\n\n', '05 Jun 2020']
# 25 ['상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트\n\n', '05 Jun 2020']
# 26 ['상품명: 피아블 클래식 방수 매트리스커버, 화이트\n\n', '05 Jun 2020']
# 27 ['상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이\n\n', '05 Jun 2020']
# 28 ['상품명: 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크\n\n', '05 Jun 2020']
# 29 ['상품명: 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이\n\n', '05 Jun 2020']
# 30 ['상품명: 아망떼 시어서커 리플 홑이불 패드세트, 웨이크\n\n', '05 Jun 2020']
# 31 ['상품명: 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이\n\n', '05 Jun 2020']
# 32 ['상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이\n\n', '05 Jun 2020']
# 33 ['상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이\n\n', '05 Jun 2020']
# 34 ['상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지\n\n', '05 Jun 2020']
# 35 ['상품명: 아망떼 시어서커 리플 홑이불 패드세트, 허브티\n\n', '05 Jun 2020']
# 36 ['상품명: 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이\n\n', '05 Jun 2020']
# 37 ['상품명: 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이\n\n', '05 Jun 2020']
# 38 ['상품명: 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우\n\n', '05 Jun 2020']
# 39 ['상품명: 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나\n\n', '05 Jun 2020']
# 40 ['상품명: 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린\n\n', '05 Jun 2020']
# 41 ['상품명: 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비\n\n', '05 Jun 2020']
# 42 ['상품명: 슈에뜨룸 비숑 피치스킨 침구세트, 그레이\n\n', '05 Jun 2020']
# 43 ['상품명: 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜\n\n', '05 Jun 2020']
# 44 ['상품명: 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜\n\n', '05 Jun 2020']
# 45 ['상품명: 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이\n\n', '05 Jun 2020']
# 46 ['상품명: 예가로드 메리엘 시어서커 누비이불 패드세트, 블루\n\n', '05 Jun 2020']
# 47 ['상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트\n\n', '05 Jun 2020']
# 48 ['상품명: 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린\n\n', '05 Jun 2020']
# 49 ['상품명: 메종 레이스 차렵 이불 세트, 블루\n\n', '05 Jun 2020']
# 50 ['상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그린\n\n', '05 Jun 2020']
# 51 ['상품명: 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상\n\n', '05 Jun 2020']
# 52 ['상품명: 보몽드 메종 레이스 차렵이불 3종 세트, 민트\n\n', '05 Jun 2020']
# 53 ['상품명: 슈에뜨룸 체크 피치스킨 침구세트, 모카\n\n', '05 Jun 2020']
# 54 ['상품명: 메리엘 시어서커 에어리플 이불세트, 그레이\n\n', '05 Jun 2020']
# 55 ['상품명: 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비\n\n', '05 Jun 2020']
# 56 ['상품명: 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트\n\n', '05 Jun 2020']
# 57 ['상품명: 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이\n\n', '05 Jun 2020']
# 58 ['상품명: 이코디 5단 엔틱 도어 행거, 브라운, 1개\n\n', '05 Jun 2020']
# 59 ['상품명: 선우랜드 우드볼 도어훅 4구, 실버, 1개\n\n', '05 Jun 2020']
# 60 ['상품명: 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개\n\n', '05 Jun 2020']
# 61 ['상품명: 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트\n\n', '05 Jun 2020']
# 62 ['상품명: 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개\n\n', '05 Jun 2020']
# 63 ['상품명: 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개\n\n', '05 Jun 2020']
# 64 ['상품명: 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개\n\n', '05 Jun 2020']
# 65 ['상품명: 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트\n\n', '05 Jun 2020']
# 66 ['상품명: 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개\n\n', '05 Jun 2020']
# 67 ['상품명: 선우랜드 우드볼 도어훅 10구, 실버, 1개\n\n', '05 Jun 2020']
# 68 ['상품명: 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개\n\n', '05 Jun 2020']
# 69 ['상품명: 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1\n\n', '05 Jun 2020']
# 70 ['상품명: 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개\n\n', '05 Jun 2020']
# 71 ['상품명: 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개\n\n', '05 Jun 2020']
# 72 ['상품명: [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량\n\n', '05 Jun 2020']
# 73 ['상품명: 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개\n\n', '05 Jun 2020']
# 74 ['상품명: 숲속애 웨이브 도어후크 5구, 블랙, 1개\n\n', '05 Jun 2020']
# 75 ['상품명: 펀타스틱 다용도 문틀걸이, 화이트, 1개\n\n', '05 Jun 2020']
# 76 ['상품명: 선우랜드 우드볼 도어훅 4구, 화이트, 1개\n\n', '05 Jun 2020']
# 77 ['상품명: 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개\n\n', '05 Jun 2020']
# 78 ['상품명: 까사마루 블랑 접이식 문걸이 건조대, 1개\n\n', '05 Jun 2020']
# 79 ['상품명: 선우랜드 우드볼 도어훅 6구, 실버, 1개\n\n', '05 Jun 2020']
# 80 ['상품명: 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개\n\n', '05 Jun 2020']
# 81 ['상품명: 선우랜드 우드볼 도어훅 10구, 화이트, 1개\n\n', '05 Jun 2020']
# 82 ['상품명: 코멧 홈 우드볼 도어행거, 6구, 혼합색상\n\n', '05 Jun 2020']
# 83 ['상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조\n\n', '05 Jun 2020']
# 84 ['상품명: 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개\n\n', '05 Jun 2020']
# 85 ['상품명: 스파이더락 도어후크 8구, 화이트, 1개\n\n', '05 Jun 2020']
# 86 ['상품명: 선우랜드 우드볼 도어훅 6구, 화이트, 1개\n\n', '05 Jun 2020']
# 87 ['상품명: 코멧 홈 우드볼 도어행거, 10구, 혼합색상\n\n', '05 Jun 2020']
# 88 ['상품명: 보드래 헬로우 누빔 매트리스커버, 핑크\n\n', '05 Jun 2020']
# 89 ['상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리\n\n', '05 Jun 2020']
# 90 ['상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키핑크\n\n', '05 Jun 2020']
# 91 ['상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고\n\n', '05 Jun 2020']
# 92 ['상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이\n\n', '05 Jun 2020']
# 93 ['상품명: 프로텍트어베드 베이직 매트리스 방수커버, 그레이\n\n', '05 Jun 2020']

# %% [markdown]
# ### 엑셀 파일 저장하기

# %%
write_excel_template('morning_practice_201221_crawling_multiple_pages.xlsx','morning_practice_201221',product_lists)

# %% [markdown]
# ### 엑셀 파일 읽어 오기

# %%
# step3 엑셀 파일 읽어오기_1
read_excel_file = openpyxl.load_workbook('morning_practice_201221_crawling_multiple_pages.xlsx')

# %%
read_excel_file.sheetnames
# Out:
# ['morning_practice_201221']

# %%
excel_sheet = read_excel_file['morning_practice_201221']

# %%
for item in excel_sheet.rows:
    print(item[0].value, item[1].value)
# Out:
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
#
#  05 Jun 2020
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
#
#  05 Jun 2020
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
#
#  05 Jun 2020
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
#
#  05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
#
#  05 Jun 2020
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
#
#  05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 프랑떼 항균 방수 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
#
#  05 Jun 2020
# 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
#
#  05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
#
#  05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트
#
#  05 Jun 2020
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
#
#  05 Jun 2020
# 상품명: 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
#
#  05 Jun 2020
# 상품명: 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
#
#  05 Jun 2020
# 상품명: 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
#
#  05 Jun 2020
# 상품명: 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
#
#  05 Jun 2020
# 상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
#
#  05 Jun 2020
# 상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
#
#  05 Jun 2020
# 상품명: 아망떼 시어서커 리플 홑이불 패드세트, 허브티
#
#  05 Jun 2020
# 상품명: 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
#
#  05 Jun 2020
# 상품명: 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
#
#  05 Jun 2020
# 상품명: 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
#
#  05 Jun 2020
# 상품명: 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
#
#  05 Jun 2020
# 상품명: 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
#
#  05 Jun 2020
# 상품명: 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 비숑 피치스킨 침구세트, 그레이
#
#  05 Jun 2020
# 상품명: 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜
#
#  05 Jun 2020
# 상품명: 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜
#
#  05 Jun 2020
# 상품명: 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이
#
#  05 Jun 2020
# 상품명: 예가로드 메리엘 시어서커 누비이불 패드세트, 블루
#
#  05 Jun 2020
# 상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트
#
#  05 Jun 2020
# 상품명: 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린
#
#  05 Jun 2020
# 상품명: 메종 레이스 차렵 이불 세트, 블루
#
#  05 Jun 2020
# 상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그린
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상
#
#  05 Jun 2020
# 상품명: 보몽드 메종 레이스 차렵이불 3종 세트, 민트
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 체크 피치스킨 침구세트, 모카
#
#  05 Jun 2020
# 상품명: 메리엘 시어서커 에어리플 이불세트, 그레이
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비
#
#  05 Jun 2020
# 상품명: 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트
#
#  05 Jun 2020
# 상품명: 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이
#
#  05 Jun 2020
# 상품명: 이코디 5단 엔틱 도어 행거, 브라운, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 4구, 실버, 1개
#
#  05 Jun 2020
# 상품명: 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
#
#  05 Jun 2020
# 상품명: 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
#
#  05 Jun 2020
# 상품명: 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
#
#  05 Jun 2020
# 상품명: 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
#
#  05 Jun 2020
# 상품명: 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
#
#  05 Jun 2020
# 상품명: 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
#
#  05 Jun 2020
# 상품명: 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 10구, 실버, 1개
#
#  05 Jun 2020
# 상품명: 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
#
#  05 Jun 2020
# 상품명: 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
#
#  05 Jun 2020
# 상품명: 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
#
#  05 Jun 2020
# 상품명: [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
#
#  05 Jun 2020
# 상품명: 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
#
#  05 Jun 2020
# 상품명: 숲속애 웨이브 도어후크 5구, 블랙, 1개
#
#  05 Jun 2020
# 상품명: 펀타스틱 다용도 문틀걸이, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 4구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
#
#  05 Jun 2020
# 상품명: 까사마루 블랑 접이식 문걸이 건조대, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 6구, 실버, 1개
#
#  05 Jun 2020
# 상품명: 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 10구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 코멧 홈 우드볼 도어행거, 6구, 혼합색상
#
#  05 Jun 2020
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
#
#  05 Jun 2020
# 상품명: 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 스파이더락 도어후크 8구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 6구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 코멧 홈 우드볼 도어행거, 10구, 혼합색상
#
#  05 Jun 2020
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
#
#  05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
#
#  05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
#
#  05 Jun 2020
# 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 프로텍트어베드 베이직 매트리스 방수커버, 그레이
#
#  05 Jun 2020

# %%
# step3 엑셀 파일 읽어오기_2

# %%
read_excel_file = openpyxl.load_workbook('morning_practice_201221_crawling_multiple_pages.xlsx')

# %%
read_excel_file.sheetnames
# Out:
# ['morning_practice_201221']

# %%
excel_sheet = read_excel_file['morning_practice_201221']

# %%
for item in excel_sheet.rows: 
    print(item[0].value, item[1].value)

# %%
# step3 엑셀 파일 읽어오기_3

# %%
read_excel_file = openpyxl.load_workbook('morning_practice_201221_crawling_multiple_pages.xlsx')

# %%
read_excel_file.sheetnames
# Out:
# ['morning_practice_201221']

# %%
excel_sheet = read_excel_file['morning_practice_201221']

# %%
for item in excel_sheet.rows: 
    print(item[0].value, item[1].value)

# %%
# step3 엑셀 파일 읽어오기_4

# %%
read_excel_file = openpyxl.load_workbook('morning_practice_201221_crawling_multiple_pages.xlsx')

# %%
read_excel_file.sheetnames
# Out:
# ['morning_practice_201221']

# %%
excel_sheet = read_excel_file['morning_practice_20201221.ipynb']

# %%
for item in excel_sheet.rows:
    print(item[0].value , item[1].value)

# %%
# step3 엑셀 파일 읽어오기_5

# %%
read_excel_file = openpyxl.load_workbook('morning_practice_201221_crawling_multiple_pages.xlsx')

# %%
read_excel_file.sheetnames
# Out:
# ['morning_practice_201221']

# %%
read_sheet = read_excel_file['morning_practice_201221']

# %%
for item in read_sheet.rows:
    print(item[0].value, item[1].value)
# Out:
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
#
#  05 Jun 2020
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
#
#  05 Jun 2020
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
#
#  05 Jun 2020
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
#
#  05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
#
#  05 Jun 2020
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
#
#  05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
#
#  05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 프랑떼 항균 방수 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
#
#  05 Jun 2020
# 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
#
#  05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
#
#  05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트
#
#  05 Jun 2020
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
#
#  05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
#
#  05 Jun 2020
# 상품명: 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
#
#  05 Jun 2020
# 상품명: 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
#
#  05 Jun 2020
# 상품명: 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
#
#  05 Jun 2020
# 상품명: 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
#
#  05 Jun 2020
# 상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
#
#  05 Jun 2020
# 상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
#
#  05 Jun 2020
# 상품명: 아망떼 시어서커 리플 홑이불 패드세트, 허브티
#
#  05 Jun 2020
# 상품명: 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
#
#  05 Jun 2020
# 상품명: 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
#
#  05 Jun 2020
# 상품명: 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
#
#  05 Jun 2020
# 상품명: 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
#
#  05 Jun 2020
# 상품명: 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
#
#  05 Jun 2020
# 상품명: 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 비숑 피치스킨 침구세트, 그레이
#
#  05 Jun 2020
# 상품명: 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜
#
#  05 Jun 2020
# 상품명: 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜
#
#  05 Jun 2020
# 상품명: 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이
#
#  05 Jun 2020
# 상품명: 예가로드 메리엘 시어서커 누비이불 패드세트, 블루
#
#  05 Jun 2020
# 상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트
#
#  05 Jun 2020
# 상품명: 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린
#
#  05 Jun 2020
# 상품명: 메종 레이스 차렵 이불 세트, 블루
#
#  05 Jun 2020
# 상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그린
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상
#
#  05 Jun 2020
# 상품명: 보몽드 메종 레이스 차렵이불 3종 세트, 민트
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 체크 피치스킨 침구세트, 모카
#
#  05 Jun 2020
# 상품명: 메리엘 시어서커 에어리플 이불세트, 그레이
#
#  05 Jun 2020
# 상품명: 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비
#
#  05 Jun 2020
# 상품명: 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트
#
#  05 Jun 2020
# 상품명: 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이
#
#  05 Jun 2020
# 상품명: 이코디 5단 엔틱 도어 행거, 브라운, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 4구, 실버, 1개
#
#  05 Jun 2020
# 상품명: 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
#
#  05 Jun 2020
# 상품명: 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
#
#  05 Jun 2020
# 상품명: 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
#
#  05 Jun 2020
# 상품명: 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
#
#  05 Jun 2020
# 상품명: 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
#
#  05 Jun 2020
# 상품명: 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
#
#  05 Jun 2020
# 상품명: 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 10구, 실버, 1개
#
#  05 Jun 2020
# 상품명: 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
#
#  05 Jun 2020
# 상품명: 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
#
#  05 Jun 2020
# 상품명: 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
#
#  05 Jun 2020
# 상품명: [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
#
#  05 Jun 2020
# 상품명: 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
#
#  05 Jun 2020
# 상품명: 숲속애 웨이브 도어후크 5구, 블랙, 1개
#
#  05 Jun 2020
# 상품명: 펀타스틱 다용도 문틀걸이, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 4구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
#
#  05 Jun 2020
# 상품명: 까사마루 블랑 접이식 문걸이 건조대, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 6구, 실버, 1개
#
#  05 Jun 2020
# 상품명: 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 10구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 코멧 홈 우드볼 도어행거, 6구, 혼합색상
#
#  05 Jun 2020
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
#
#  05 Jun 2020
# 상품명: 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 스파이더락 도어후크 8구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 선우랜드 우드볼 도어훅 6구, 화이트, 1개
#
#  05 Jun 2020
# 상품명: 코멧 홈 우드볼 도어행거, 10구, 혼합색상
#
#  05 Jun 2020
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
#
#  05 Jun 2020
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
#
#  05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
#
#  05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
#
#  05 Jun 2020
# 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
#
#  05 Jun 2020
# 상품명: 프로텍트어베드 베이직 매트리스 방수커버, 그레이
#
#  05 Jun 2020

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_1_1

# %%
import requests
import pprint

client_id = 'BTMVavws8Is7jmVpUcSL'
clidnet_secret = 'sDgiapg86l'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=간장'
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'], item['link'])
else:
    print("Error Code:", res.status_code)

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_1_2

# %%
import requests
import pprint
client_id = 'BTMVavws8Is7jmVpUcSL'
client_secret = 'sDgiapg86l'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=갤럭시노트10'
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'], item['link'])
else:
    print("Error Code:", res.status_code)

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_1_3

# %%
import requests
import pprint
client_id = 'BTMVavws8Is7jmVpUcSL'
client_secret = 'sDgiapg86l'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=갤럭시노트10'
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, header=header_params)

if res.status_code ==200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index +1, item['title'], item['link'])
else:
    print("Error Code:", res.status_code)

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_1_4

# %%
import requests
import pprint

client_id ='BTMVavws8Is7jmVpUcSL'
client_secret = 'sDgiapg86l'

naver_open_api ='https://openapi.naver.com/v1/search/shop.json?query=갤럭시노트10'
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}

res = requests.get(naver_open_api, header=header)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index+1, item['title'], item['link'])
    else:
        print("Error COde:", res.status_code)

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_1_5

# %%
import requests
import pprint

client_id =''
client_secret =''

naver_open_api = ''
header_params = {}

res = requests.get(naver_open_api, header=header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index+1, item['title'], item['link'])
    else:
        print("Error Code:", res.status_code)

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_2_1

# %%
import requests
import openpyxl 

client_id = ''
client_secret = ''
start, num = 1,0 

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.activ
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹','제목','링크'])

for index in range(10):
    start_number = start + (index*100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=샤오미&display=100&start=' + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num +=1
            excel_sheet.append([num,item['title'], item['link']])
    else:
        print("Error Code:", res.status_code)
excel_file.save('IT.xlsx')
excel_file.close()

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_2_2

# %%
import requests
import openpyxl 
start = 1
num = 0
client_id =''
client_secret = ''

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=간장&display=100&start=' + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for index, item in enumerate(data['items']):
            num +=1
            excel_sheet.append([num, item['title'], item['link']])
    else:
        print("Error Code:", res.status_code)
excel_file.save('IT.xlsx')
excel_file.close()

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_2_3

# %%
import requests
import openpyxl
start = 1
num = 0
client_id = ''
client_secret = ''

excel_file = openpyxl.Workbook()
excel_sheet= excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=간장&display=100&start='+str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for index, item in enumerate(data['items']):
            num+=1
            excel_sheet.append([num,item['title'],item['link']])
    else:
        print("Error Code:", res.status_code)
excel_file.save('IT.xlsx')
excel_file.close()

# %%
# STEP4. 네이버 api이용하고 엑셀 파일로 저장하기. (json형식)_2_4
import requests
import openpyxl
start = 1
num = 0
client_id = ''
client_secret = ''

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100

for index in range(10):
    start_num = num + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=간장&display=100&start='+str(start_num)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=headr_params)
    if res.status_code == 200:
        data = res.json()
        for index, item in enumerate(data):
            num+=1
            excel_sheet.append([num,item['title'],item['link']])
    else:
        print("Error Code", res.status_code)
excel_file.save('IT.xlsx')
excel_file.close()

# %%
import requests
import openpyxl
start = 1
num =0
client_id = '9DdQYYWtoOpgrw1YWAYZ'
client_secret = 'dq175srVEK'
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100

for index in range(10):
    start_num = start + (index*100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=간장&display=100&start='+str(start_num)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res=requests.get(naver_open_api,headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num+=1
            excel_sheet.append([num,item['title'],item['link']])
    else:
        print("Error Code", res.status_code)
excel_file.save('IT.xlsx')
excel_file.close()
